# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile('cifar-10-python.tar.gz'):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            'cifar-10-python.tar.gz',
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open('cifar-10-python.tar.gz') as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 5
sample_id = 10
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-04f052d20c9f> in <module>()
#       8 batch_id = 5
#       9 sample_id = 10
# ---> 10 helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
#
# NameError: name 'cifar10_dataset_folder_path' is not defined

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
    max_x = np.max(x)
    norm_data = x /max_x
    return norm_data


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # TODO: Implement Function
    one_hot = np.zeros((len(x),10))
    # set up the one_hot 
    for i in range(len(x)):
        one_hot[i][x[i]] = 1
    return one_hot


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a bach of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    tensor_input = tf.placeholder(tf.float32, 
                                  shape=[None,image_shape[0],image_shape[1],image_shape[2]],
                                 name="x")
    return tensor_input


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    tensor_labels = tf.placeholder(tf.float32, shape=[None,n_classes], name='y') 
    return tensor_labels


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, name="keep_prob")


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # TODO: Implement Function
    # form the shape of the weights
    num_input_channels = x_tensor.shape[3].value
    weights_shape = [conv_ksize[0],conv_ksize[1], num_input_channels,conv_num_outputs]
    # generate weights
    filters = tf.Variable(tf.truncated_normal(weights_shape, stddev=0.05))
    # biases
    biases = tf.Variable(tf.zeros(conv_num_outputs))
    
    # create the convolution layer
    strides_conv_shape = [1,conv_strides[0],conv_strides[1],1]
    #print(strides_conv_shape)
    conv_layer = tf.nn.conv2d(x_tensor, 
                              filter=filters, 
                              strides=strides_conv_shape, 
                              padding='SAME' )
    # add biases
    conv_layer_plus_bias = tf.nn.bias_add(conv_layer, biases)
    
    # apply relu here
    relu_layer = tf.nn.relu(conv_layer_plus_bias)
    
    # max_pool     
    # shape of max pool 
    strides_pool_shape = [1, pool_strides[0], pool_strides[1], 1]
    ksize_shape = [1,pool_ksize[0],pool_ksize[1],1]
    #print(strides_pool_shape)
    max_pool_layer = tf.nn.max_pool(relu_layer, 
                                    ksize=ksize_shape, 
                                    strides=strides_pool_shape, 
                                    padding='SAME')
    
    
    
    return max_pool_layer 


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    num_cols = x_tensor.shape[1].value * x_tensor.shape[2].value * x_tensor.shape[3].value
    flatten_layer = tf.reshape(x_tensor,shape=[-1,num_cols])
    return flatten_layer


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    weights_shape = [x_tensor.shape[1].value, num_outputs]
    weights = tf.Variable(tf.truncated_normal(shape=weights_shape,stddev=0.1))
    biases = tf.Variable(tf.constant(0.0,shape=[num_outputs]))
    
    fc_layer = tf.add(tf.matmul(x_tensor,weights),biases)
    
    return fc_layer


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    weights_shape = [x_tensor.shape[1].value,num_outputs]
    weights = tf.Variable(tf.truncated_normal(shape=weights_shape, stddev=0.1))
    biases = tf.Variable(tf.constant(0.0,shape=[num_outputs]))
    
    output = tf.add(tf.matmul(x_tensor,weights),biases)
    
    return output


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
conv_num_outputs = 16
conv_ksize = [5,5]
conv_strides = [1,1]
pool_ksize = [2,2]
pool_strides = [1,1]
fc_num_outputs = 128
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    conv_layer1 = conv2d_maxpool(x, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    conv_layer2 = conv2d_maxpool(conv_layer1, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    conv_layer3 = conv2d_maxpool(conv_layer2, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    

    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    flatten_layer = flatten(conv_layer3)
    


    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    # FC layer 1 with relu
    fc_layer_1 = fully_conn(flatten_layer, fc_num_outputs)
    fc_layer1_relu = tf.nn.relu(fc_layer_1)
    # FC layer 2 with relu
    fc_layer_2 = fully_conn(fc_layer1_relu, fc_num_outputs)
    fc_layer2_relu = tf.nn.relu(fc_layer_2)
    # FC layer 3 with relu
    fc_layer_3 = fully_conn(fc_layer2_relu, fc_num_outputs)
    fc_layer3_relu = tf.nn.relu(fc_layer_3)
    fc_layer3_dropout = tf.nn.dropout(fc_layer3_relu, keep_prob)
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    output_layer= output(fc_layer3_dropout, 10)
    
    return output_layer


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

croped_size = 32

# Inputs
x = neural_net_image_input((croped_size, croped_size, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

#print(logits)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    session.run(optimizer, feed_dict={x:feature_batch, y:label_batch, keep_prob:keep_probability})


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    cost_val = session.run(cost, feed_dict={x:feature_batch,y:label_batch,keep_prob:1.0})
    #acc = session.run(accuracy,feed_dict={x:valid_features_distored, y:valid_labels, keep_prob:1.0})
    acc = session.run(accuracy,feed_dict={x:valid_features, y:valid_labels, keep_prob:1.0})
    print ("Cost: "+str(cost_val))
    print("Accuracy: "+str(acc))
    print("======================")

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 50
batch_size = 256
keep_probability = 0.5

# %%
# data augmentation from keras 
from keras.preprocessing.image import ImageDataGenerator
datagen = ImageDataGenerator(
        shear_range=0.3, 
        zoom_range=0.3,
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=40,  # randomly rotate images in the range (degrees, 0 to 180)
        width_shift_range=0.2,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.2,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=True,  # randomly flip images
        vertical_flip=False)  # randomly flip image
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np
import gc
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        # load features and labels from data source 
        features,labels = helper.load_preprocess_data(batch_i)
        # counter to stop when training enough batches as keras will loop infite on image iterator
        count = 0
        # number of batches to stop
        stop_at = np.ceil(len(features)/batch_size)
        print("ready for training")
         # use keras to agumented the data in the loop
        for batch_features, batch_labels in datagen.flow(features,labels, batch_size=batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            # check if we need to stop
            if (count >= stop_at):
                break
            count += 1
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print("\n")
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
        gc.collect()
    # close session to avoid memory error 
    sess.close()
# Out:
# Checking the Training on a Single Batch...
# ready for training
# Epoch  1, CIFAR-10 Batch 1:
#
# Cost: 2.08199
# Accuracy: 0.2258
# ======================
# ready for training
# Epoch  2, CIFAR-10 Batch 1:
#
# Cost: 2.04288
# Accuracy: 0.2722
# ======================
# ready for training
# Epoch  3, CIFAR-10 Batch 1:
#
# Cost: 1.89448
# Accuracy: 0.3282
# ======================
# ready for training
# Epoch  4, CIFAR-10 Batch 1:
#
# Cost: 1.93204
# Accuracy: 0.2924
# ======================
# ready for training
# Epoch  5, CIFAR-10 Batch 1:
#
# Cost: 1.81518
# Accuracy: 0.3888
# ======================
# ready for training
# Epoch  6, CIFAR-10 Batch 1:
#
# Cost: 1.80154
# Accuracy: 0.3664
# ======================
# ready for training
# Epoch  7, CIFAR-10 Batch 1:
#
# Cost: 1.67521
# Accuracy: 0.4132
# ======================
# ready for training
# Epoch  8, CIFAR-10 Batch 1:
#
# Cost: 1.55689
# Accuracy: 0.449
# ======================
# ready for training
# Epoch  9, CIFAR-10 Batch 1:
#
# Cost: 1.61998
# Accuracy: 0.4544
# ======================
# ready for training
# Epoch 10, CIFAR-10 Batch 1:
#
# Cost: 1.59572
# Accuracy: 0.438
# ======================
# ready for training
# Epoch 11, CIFAR-10 Batch 1:
#
# Cost: 1.55203
# Accuracy: 0.4558
# ======================
# ready for training
# Epoch 12, CIFAR-10 Batch 1:
#
# Cost: 1.63049
# Accuracy: 0.462
# ======================
# ready for training
# Epoch 13, CIFAR-10 Batch 1:
#
# Cost: 1.48659
# Accuracy: 0.4856
# ======================
# ready for training
# Epoch 14, CIFAR-10 Batch 1:
#
# Cost: 1.61225
# Accuracy: 0.4654
# ======================
# ready for training
# Epoch 15, CIFAR-10 Batch 1:
#
# Cost: 1.58754
# Accuracy: 0.484
# ======================
# ready for training
# Epoch 16, CIFAR-10 Batch 1:
#
# Cost: 1.41262
# Accuracy: 0.481
# ======================
# ready for training
# Epoch 17, CIFAR-10 Batch 1:
#
# Cost: 1.62117
# Accuracy: 0.4884
# ======================
# ready for training
# Epoch 18, CIFAR-10 Batch 1:
#
# Cost: 1.50367
# Accuracy: 0.507
# ======================
# ready for training
# Epoch 19, CIFAR-10 Batch 1:
#
# Cost: 1.46253
# Accuracy: 0.486
# ======================
# ready for training
# Epoch 20, CIFAR-10 Batch 1:
#
# Cost: 1.53532
# Accuracy: 0.4562
# ======================
# ready for training
# Epoch 21, CIFAR-10 Batch 1:
#
# Cost: 1.48311
# Accuracy: 0.5028
# ======================
# ready for training
# Epoch 22, CIFAR-10 Batch 1:
#
# Cost: 1.42486
# Accuracy: 0.5132
# ======================
# ready for training
# Epoch 23, CIFAR-10 Batch 1:
#
# Cost: 1.36674
# Accuracy: 0.5066
# ======================
# ready for training
# Epoch 24, CIFAR-10 Batch 1:
#
# Cost: 1.44365
# Accuracy: 0.4814
# ======================
# ready for training
# Epoch 25, CIFAR-10 Batch 1:
#
# Cost: 1.3444
# Accuracy: 0.5284
# ======================
# ready for training
# Epoch 26, CIFAR-10 Batch 1:
#
# Cost: 1.40438
# Accuracy: 0.521
# ======================
# ready for training
# Epoch 27, CIFAR-10 Batch 1:
#
# Cost: 1.36596
# Accuracy: 0.4944
# ======================
# ready for training
# Epoch 28, CIFAR-10 Batch 1:
#
# Cost: 1.41077
# Accuracy: 0.5078
# ======================
# ready for training
# Epoch 29, CIFAR-10 Batch 1:
#
# Cost: 1.36482
# Accuracy: 0.5364
# ======================
# ready for training
# Epoch 30, CIFAR-10 Batch 1:
#
# Cost: 1.32949
# Accuracy: 0.5388
# ======================

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'
import numpy as np
import gc
print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            features,labels = helper.load_preprocess_data(batch_i)
            # counter to stop when training enough batches as keras will loop infite on image iterator
            count = 0
            # number of batches to stop
            stop_at = np.ceil(len(features)/batch_size)
            print("ready for training")
            # use keras to agumented the data in the loop
            for batch_features, batch_labels in datagen.flow(features,labels, batch_size=batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
                # check if we need to stop
                if (count >= stop_at):
                    break
                count += 1
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            batch_features = None
            batch_labels = None
            feature = None
            labels = None
            gc.collect()
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
    sess.close()
# Out:
# Training...
# ready for training
# Epoch  1, CIFAR-10 Batch 1:  Cost: 1.97546
# Accuracy: 0.2592
# ======================
# ready for training
# Epoch  1, CIFAR-10 Batch 2:  Cost: 1.86016
# Accuracy: 0.368
# ======================
# ready for training
# Epoch  1, CIFAR-10 Batch 3:  Cost: 1.76249
# Accuracy: 0.399
# ======================
# ready for training
# Epoch  1, CIFAR-10 Batch 4:  Cost: 1.82059
# Accuracy: 0.3506
# ======================
# ready for training
# Epoch  1, CIFAR-10 Batch 5:  Cost: 1.71398
# Accuracy: 0.4148
# ======================
# ready for training
# Epoch  2, CIFAR-10 Batch 1:  Cost: 1.75954
# Accuracy: 0.4026
# ======================
# ready for training
# Epoch  2, CIFAR-10 Batch 2:  Cost: 1.72343
# Accuracy: 0.4352
# ======================
# ready for training
# Epoch  2, CIFAR-10 Batch 3:  Cost: 1.72121
# Accuracy: 0.4064
# ======================
# ready for training
# Epoch  2, CIFAR-10 Batch 4:  Cost: 1.59033
# Accuracy: 0.4448
# ======================
# ready for training
# Epoch  2, CIFAR-10 Batch 5:  Cost: 1.73683
# Accuracy: 0.4484
# ======================
# ready for training
# Epoch  3, CIFAR-10 Batch 1:  Cost: 1.576
# Accuracy: 0.4704
# ======================
# ready for training
# Epoch  3, CIFAR-10 Batch 2:  Cost: 1.72272
# Accuracy: 0.4608
# ======================
# ready for training
# Epoch  3, CIFAR-10 Batch 3:  Cost: 1.60858
# Accuracy: 0.4486
# ======================
# ready for training
# Epoch  3, CIFAR-10 Batch 4:  Cost: 1.61491
# Accuracy: 0.4694
# ======================
# ready for training
# Epoch  3, CIFAR-10 Batch 5:  Cost: 1.60045
# Accuracy: 0.4818
# ======================
# ready for training
# Epoch  4, CIFAR-10 Batch 1:  Cost: 1.60693
# Accuracy: 0.469
# ======================
# ready for training
# Epoch  4, CIFAR-10 Batch 2:  Cost: 1.56719
# Accuracy: 0.4944
# ======================
# ready for training
# Epoch  4, CIFAR-10 Batch 3:  Cost: 1.46354
# Accuracy: 0.4816
# ======================
# ready for training
# Epoch  4, CIFAR-10 Batch 4:  Cost: 1.54672
# Accuracy: 0.4942
# ======================
# ready for training
# Epoch  4, CIFAR-10 Batch 5:  Cost: 1.54929
# Accuracy: 0.4704
# ======================
# ready for training
# Epoch  5, CIFAR-10 Batch 1:  Cost: 1.53057
# Accuracy: 0.4654
# ======================
# ready for training
# Epoch  5, CIFAR-10 Batch 2:  Cost: 1.46591
# Accuracy: 0.5136
# ======================
# ready for training
# Epoch  5, CIFAR-10 Batch 3:  Cost: 1.47356
# Accuracy: 0.489
# ======================
# ready for training
# Epoch  5, CIFAR-10 Batch 4:  Cost: 1.56312
# Accuracy: 0.5122
# ======================
# ready for training
# Epoch  5, CIFAR-10 Batch 5:  Cost: 1.32747
# Accuracy: 0.5184
# ======================
# ready for training
# Epoch  6, CIFAR-10 Batch 1:  Cost: 1.46234
# Accuracy: 0.5244
# ======================
# ready for training
# Epoch  6, CIFAR-10 Batch 2:  Cost: 1.42984
# Accuracy: 0.5352
# ======================
# ready for training
# Epoch  6, CIFAR-10 Batch 3:  Cost: 1.50315
# Accuracy: 0.5066
# ======================
# ready for training
# Epoch  6, CIFAR-10 Batch 4:  Cost: 1.45308
# Accuracy: 0.5192
# ======================
# ready for training
# Epoch  6, CIFAR-10 Batch 5:  Cost: 1.51357
# Accuracy: 0.5106
# ======================
# ready for training
# Epoch  7, CIFAR-10 Batch 1:  Cost: 1.44857
# Accuracy: 0.5224
# ======================
# ready for training
# Epoch  7, CIFAR-10 Batch 2:  Cost: 1.36382
# Accuracy: 0.5418
# ======================
# ready for training
# Epoch  7, CIFAR-10 Batch 3:  Cost: 1.35736
# Accuracy: 0.5438
# ======================
# ready for training
# Epoch  7, CIFAR-10 Batch 4:  Cost: 1.46981
# Accuracy: 0.5382
# ======================
# ready for training
# Epoch  7, CIFAR-10 Batch 5:  Cost: 1.33734
# Accuracy: 0.5428
# ======================
# ready for training
# Epoch  8, CIFAR-10 Batch 1:  Cost: 1.43988
# Accuracy: 0.5356
# ======================
# ready for training
# Epoch  8, CIFAR-10 Batch 2:  Cost: 1.64712
# Accuracy: 0.5146
# ======================
# ready for training
# Epoch  8, CIFAR-10 Batch 3:  Cost: 1.34626
# Accuracy: 0.546
# ======================
# ready for training
# Epoch  8, CIFAR-10 Batch 4:  Cost: 1.41068
# Accuracy: 0.545
# ======================
# ready for training
# Epoch  8, CIFAR-10 Batch 5:  Cost: 1.34823
# Accuracy: 0.5482
# ======================
# ready for training
# Epoch  9, CIFAR-10 Batch 1:  Cost: 1.3501
# Accuracy: 0.5524
# ======================
# ready for training
# Epoch  9, CIFAR-10 Batch 2:  Cost: 1.43411
# Accuracy: 0.5496
# ======================
# ready for training
# Epoch  9, CIFAR-10 Batch 3:  Cost: 1.39473
# Accuracy: 0.5558
# ======================
# ready for training
# Epoch  9, CIFAR-10 Batch 4:  Cost: 1.33169
# Accuracy: 0.5704
# ======================
# ready for training
# Epoch  9, CIFAR-10 Batch 5:  Cost: 1.39013
# Accuracy: 0.5282
# ======================
# ready for training
# Epoch 10, CIFAR-10 Batch 1:  Cost: 1.44383
# Accuracy: 0.5632
# ======================
# ready for training
# Epoch 10, CIFAR-10 Batch 2:  Cost: 1.36922
# Accuracy: 0.5598
# ======================
# ready for training
# Epoch 10, CIFAR-10 Batch 3:  Cost: 1.34151
# Accuracy: 0.5544
# ======================
# ready for training
# Epoch 10, CIFAR-10 Batch 4:  Cost: 1.26432
# Accuracy: 0.5584
# ======================
# ready for training
# Epoch 10, CIFAR-10 Batch 5:  Cost: 1.43615
# Accuracy: 0.5562
# ======================
# ready for training
# Epoch 11, CIFAR-10 Batch 1:  Cost: 1.35583
# Accuracy: 0.5584
# ======================
# ready for training
# Epoch 11, CIFAR-10 Batch 2:  Cost: 1.31251
# Accuracy: 0.578
# ======================
# ready for training
# Epoch 11, CIFAR-10 Batch 3:  Cost: 1.2054
# Accuracy: 0.5742
# ======================
# ready for training
# Epoch 11, CIFAR-10 Batch 4:  Cost: 1.41729
# Accuracy: 0.5542
# ======================
# ready for training
# Epoch 11, CIFAR-10 Batch 5:  Cost: 1.34869
# Accuracy: 0.5792
# ======================
# ready for training
# Epoch 12, CIFAR-10 Batch 1:  Cost: 1.20374
# Accuracy: 0.5738
# ======================
# ready for training
# Epoch 12, CIFAR-10 Batch 2:  Cost: 1.34161
# Accuracy: 0.5734
# ======================
# ready for training
# Epoch 12, CIFAR-10 Batch 3:  Cost: 1.35677
# Accuracy: 0.562
# ======================
# ready for training
# Epoch 12, CIFAR-10 Batch 4:  Cost: 1.38797
# Accuracy: 0.583
# ======================
# ready for training
# Epoch 12, CIFAR-10 Batch 5:  Cost: 1.41829
# Accuracy: 0.5608
# ======================
# ready for training
# Epoch 13, CIFAR-10 Batch 1:  Cost: 1.44512
# Accuracy: 0.5758
# ======================
# ready for training
# Epoch 13, CIFAR-10 Batch 2:  Cost: 1.2809
# Accuracy: 0.585
# ======================
# ready for training
# Epoch 13, CIFAR-10 Batch 3:  Cost: 1.29063
# Accuracy: 0.5878
# ======================
# ready for training
# Epoch 13, CIFAR-10 Batch 4:  Cost: 1.30137
# Accuracy: 0.5896
# ======================
# ready for training
# Epoch 13, CIFAR-10 Batch 5:  Cost: 1.38252
# Accuracy: 0.5762
# ======================
# ready for training
# Epoch 14, CIFAR-10 Batch 1:  Cost: 1.34076
# Accuracy: 0.5626
# ======================
# ready for training
# Epoch 14, CIFAR-10 Batch 2:  Cost: 1.28054
# Accuracy: 0.5732
# ======================
# ready for training
# Epoch 14, CIFAR-10 Batch 3:  Cost: 1.31702
# Accuracy: 0.5716
# ======================
# ready for training
# Epoch 14, CIFAR-10 Batch 4:  Cost: 1.34313
# Accuracy: 0.5682
# ======================
# ready for training
# Epoch 14, CIFAR-10 Batch 5:  Cost: 1.14932
# Accuracy: 0.5842
# ======================
# ready for training
# Epoch 15, CIFAR-10 Batch 1:  Cost: 1.3181
# Accuracy: 0.5886
# ======================
# ready for training
# Epoch 15, CIFAR-10 Batch 2:  Cost: 1.3436
# Accuracy: 0.576
# ======================
# ready for training
# Epoch 15, CIFAR-10 Batch 3:  Cost: 1.30502
# Accuracy: 0.558
# ======================
# ready for training
# Epoch 15, CIFAR-10 Batch 4:  Cost: 1.33847
# Accuracy: 0.5716
# ======================
# ready for training
# Epoch 15, CIFAR-10 Batch 5:  Cost: 1.22296
# Accuracy: 0.5968
# ======================
# ready for training
# Epoch 16, CIFAR-10 Batch 1:  Cost: 1.2963
# Accuracy: 0.585
# ======================
# ready for training
# Epoch 16, CIFAR-10 Batch 2:  Cost: 1.47952
# Accuracy: 0.5766
# ======================
# ready for training
# Epoch 16, CIFAR-10 Batch 3:  Cost: 1.34352
# Accuracy: 0.5734
# ======================
# ready for training
# Epoch 16, CIFAR-10 Batch 4:  Cost: 1.24212
# Accuracy: 0.5876
# ======================
# ready for training
# Epoch 16, CIFAR-10 Batch 5:  Cost: 1.27171
# Accuracy: 0.5986
# ======================
# ready for training
# Epoch 17, CIFAR-10 Batch 1:  Cost: 1.31966
# Accuracy: 0.5984
# ======================
# ready for training
# Epoch 17, CIFAR-10 Batch 2:  Cost: 1.21265
# Accuracy: 0.5908
# ======================
# ready for training
# Epoch 17, CIFAR-10 Batch 3:  Cost: 1.33012
# Accuracy: 0.5934
# ======================
# ready for training
# Epoch 17, CIFAR-10 Batch 4:  Cost: 1.355
# Accuracy: 0.5878
# ======================
# ready for training
# Epoch 17, CIFAR-10 Batch 5:  Cost: 1.35812
# Accuracy: 0.6008
# ======================
# ready for training
# Epoch 18, CIFAR-10 Batch 1:  Cost: 1.25022
# Accuracy: 0.6124
# ======================
# ready for training
# Epoch 18, CIFAR-10 Batch 2:  Cost: 1.15931
# Accuracy: 0.5914
# ======================
# ready for training
# Epoch 18, CIFAR-10 Batch 3:  Cost: 1.16639
# Accuracy: 0.602
# ======================
# ready for training
# Epoch 18, CIFAR-10 Batch 4:  Cost: 1.28166
# Accuracy: 0.6078
# ======================
# ready for training
# Epoch 18, CIFAR-10 Batch 5:  Cost: 1.18735
# Accuracy: 0.6156
# ======================
# ready for training
# Epoch 19, CIFAR-10 Batch 1:  Cost: 1.18394
# Accuracy: 0.6
# ======================
# ready for training
# Epoch 19, CIFAR-10 Batch 2:  Cost: 1.28857
# Accuracy: 0.5924
# ======================
# ready for training
# Epoch 19, CIFAR-10 Batch 3:  Cost: 1.09462
# Accuracy: 0.6022
# ======================
# ready for training
# Epoch 19, CIFAR-10 Batch 4:  Cost: 1.31861
# Accuracy: 0.5984
# ======================
# ready for training
# Epoch 19, CIFAR-10 Batch 5:  Cost: 1.25322
# Accuracy: 0.5946
# ======================
# ready for training
# Epoch 20, CIFAR-10 Batch 1:  Cost: 1.29304
# Accuracy: 0.5932
# ======================
# ready for training
# Epoch 20, CIFAR-10 Batch 2:  Cost: 1.30782
# Accuracy: 0.62
# ======================
# ready for training
# Epoch 20, CIFAR-10 Batch 3:  Cost: 1.15909
# Accuracy: 0.5866
# ======================
# ready for training
# Epoch 20, CIFAR-10 Batch 4:  Cost: 1.40508
# Accuracy: 0.5936
# ======================
# ready for training
# Epoch 20, CIFAR-10 Batch 5:  Cost: 1.14678
# Accuracy: 0.6036
# ======================
# ready for training
# Epoch 21, CIFAR-10 Batch 1:  Cost: 1.42516
# Accuracy: 0.5482
# ======================
# ready for training
# Epoch 21, CIFAR-10 Batch 2:  Cost: 1.28706
# Accuracy: 0.589
# ======================
# ready for training
# Epoch 21, CIFAR-10 Batch 3:  Cost: 1.19515
# Accuracy: 0.6036
# ======================
# ready for training
# Epoch 21, CIFAR-10 Batch 4:  Cost: 1.21653
# Accuracy: 0.6108
# ======================
# ready for training
# Epoch 21, CIFAR-10 Batch 5:  Cost: 1.22577
# Accuracy: 0.61
# ======================
# ready for training
# Epoch 22, CIFAR-10 Batch 1:  Cost: 1.26207
# Accuracy: 0.6144
# ======================
# ready for training
# Epoch 22, CIFAR-10 Batch 2:  Cost: 1.46255
# Accuracy: 0.591
# ======================
# ready for training
# Epoch 22, CIFAR-10 Batch 3:  Cost: 1.18578
# Accuracy: 0.6174
# ======================
# ready for training
# Epoch 22, CIFAR-10 Batch 4:  Cost: 1.32477
# Accuracy: 0.5932
# ======================
# ready for training
# Epoch 22, CIFAR-10 Batch 5:  Cost: 1.20859
# Accuracy: 0.6002
# ======================
# ready for training
# Epoch 23, CIFAR-10 Batch 1:  Cost: 1.18323
# Accuracy: 0.6232
# ======================
# ready for training
# Epoch 23, CIFAR-10 Batch 2:  Cost: 1.13992
# Accuracy: 0.6018
# ======================
# ready for training
# Epoch 23, CIFAR-10 Batch 3:  Cost: 1.20777
# Accuracy: 0.617
# ======================
# ready for training
# Epoch 23, CIFAR-10 Batch 4:  Cost: 1.3208
# Accuracy: 0.586
# ======================
# ready for training
# Epoch 23, CIFAR-10 Batch 5:  Cost: 1.24535
# Accuracy: 0.6102
# ======================
# ready for training
# Epoch 24, CIFAR-10 Batch 1:  Cost: 1.28948
# Accuracy: 0.6148
# ======================
# ready for training
# Epoch 24, CIFAR-10 Batch 2:  Cost: 1.1255
# Accuracy: 0.6168
# ======================
# ready for training
# Epoch 24, CIFAR-10 Batch 3:  Cost: 1.12642
# Accuracy: 0.6204
# ======================
# ready for training
# Epoch 24, CIFAR-10 Batch 4:  Cost: 1.2076
# Accuracy: 0.6154
# ======================
# ready for training
# Epoch 24, CIFAR-10 Batch 5:  Cost: 1.17442
# Accuracy: 0.6094
# ======================
# ready for training
# Epoch 25, CIFAR-10 Batch 1:  Cost: 1.19732
# Accuracy: 0.5844
# ======================
# ready for training
# Epoch 25, CIFAR-10 Batch 2:  Cost: 1.12818
# Accuracy: 0.616
# ======================
# ready for training
# Epoch 25, CIFAR-10 Batch 3:  Cost: 1.27139
# Accuracy: 0.6168
# ======================
# ready for training
# Epoch 25, CIFAR-10 Batch 4:  Cost: 1.20056
# Accuracy: 0.6056
# ======================
# ready for training
# Epoch 25, CIFAR-10 Batch 5:  Cost: 1.35513
# Accuracy: 0.581
# ======================
# ready for training
# Epoch 26, CIFAR-10 Batch 1:  Cost: 1.38974
# Accuracy: 0.6228
# ======================
# ready for training
# Epoch 26, CIFAR-10 Batch 2:  Cost: 1.12876
# Accuracy: 0.6162
# ======================
# ready for training
# Epoch 26, CIFAR-10 Batch 3:  Cost: 1.23077
# Accuracy: 0.5924
# ======================
# ready for training
# Epoch 26, CIFAR-10 Batch 4:  Cost: 1.13106
# Accuracy: 0.6254
# ======================
# ready for training
# Epoch 26, CIFAR-10 Batch 5:  Cost: 1.39149
# Accuracy: 0.5968
# ======================
# ready for training
# Epoch 27, CIFAR-10 Batch 1:  Cost: 1.18528
# Accuracy: 0.6254
# ======================
# ready for training
# Epoch 27, CIFAR-10 Batch 2:  Cost: 1.36897
# Accuracy: 0.57
# ======================
# ready for training
# Epoch 27, CIFAR-10 Batch 3:  Cost: 1.24527
# Accuracy: 0.6166
# ======================
# ready for training
# Epoch 27, CIFAR-10 Batch 4:  Cost: 1.18196
# Accuracy: 0.6308
# ======================
# ready for training
# Epoch 27, CIFAR-10 Batch 5:  Cost: 1.06069
# Accuracy: 0.6288
# ======================
# ready for training
# Epoch 28, CIFAR-10 Batch 1:  Cost: 1.22951
# Accuracy: 0.6206
# ======================
# ready for training
# Epoch 28, CIFAR-10 Batch 2:  Cost: 1.19101
# Accuracy: 0.6174
# ======================
# ready for training
# Epoch 28, CIFAR-10 Batch 3:  Cost: 1.12922
# Accuracy: 0.6222
# ======================
# ready for training
# Epoch 28, CIFAR-10 Batch 4:  Cost: 1.22028
# Accuracy: 0.6088
# ======================
# ready for training
# Epoch 28, CIFAR-10 Batch 5:  Cost: 1.33858
# Accuracy: 0.6056
# ======================
# ready for training
# Epoch 29, CIFAR-10 Batch 1:  Cost: 1.20444
# Accuracy: 0.6224
# ======================
# ready for training
# Epoch 29, CIFAR-10 Batch 2:  Cost: 1.20554
# Accuracy: 0.6216
# ======================
# ready for training
# Epoch 29, CIFAR-10 Batch 3:  Cost: 1.2182
# Accuracy: 0.6302
# ======================
# ready for training
# Epoch 29, CIFAR-10 Batch 4:  Cost: 1.22908
# Accuracy: 0.6306
# ======================
# ready for training
# Epoch 29, CIFAR-10 Batch 5:  Cost: 1.32197
# Accuracy: 0.586
# ======================
# ready for training
# Epoch 30, CIFAR-10 Batch 1:  Cost: 1.15402
# Accuracy: 0.6324
# ======================
# ready for training
# Epoch 30, CIFAR-10 Batch 2:  Cost: 1.32098
# Accuracy: 0.626
# ======================
# ready for training
# Epoch 30, CIFAR-10 Batch 3:  Cost: 1.2469
# Accuracy: 0.6138
# ======================
# ready for training
# Epoch 30, CIFAR-10 Batch 4:  Cost: 1.10719
# Accuracy: 0.6308
# ======================
# ready for training
# Epoch 30, CIFAR-10 Batch 5:  Cost: 1.17424
# Accuracy: 0.6332
# ======================
# ready for training
# Epoch 31, CIFAR-10 Batch 1:  Cost: 1.09205
# Accuracy: 0.6366
# ======================
# ready for training
# Epoch 31, CIFAR-10 Batch 2:  Cost: 1.17028
# Accuracy: 0.6292
# ======================
# ready for training
# Epoch 31, CIFAR-10 Batch 3:  Cost: 1.25734
# Accuracy: 0.6188
# ======================
# ready for training
# Epoch 31, CIFAR-10 Batch 4:  Cost: 1.13292
# Accuracy: 0.637
# ======================
# ready for training
# Epoch 31, CIFAR-10 Batch 5:  Cost: 1.22879
# Accuracy: 0.6022
# ======================
# ready for training
# Epoch 32, CIFAR-10 Batch 1:  Cost: 1.13289
# Accuracy: 0.6312
# ======================
# ready for training
# Epoch 32, CIFAR-10 Batch 2:  Cost: 1.1882
# Accuracy: 0.6188
# ======================
# ready for training
# Epoch 32, CIFAR-10 Batch 3:  Cost: 1.24629
# Accuracy: 0.6418
# ======================
# ready for training
# Epoch 32, CIFAR-10 Batch 4:  Cost: 1.31752
# Accuracy: 0.5826
# ======================
# ready for training
# Epoch 32, CIFAR-10 Batch 5:  Cost: 1.23751
# Accuracy: 0.6146
# ======================
# ready for training
# Epoch 33, CIFAR-10 Batch 1:  Cost: 1.32756
# Accuracy: 0.6028
# ======================
# ready for training
# Epoch 33, CIFAR-10 Batch 2:  Cost: 1.1095
# Accuracy: 0.637
# ======================
# ready for training
# Epoch 33, CIFAR-10 Batch 3:  Cost: 1.14809
# Accuracy: 0.605
# ======================
# ready for training
# Epoch 33, CIFAR-10 Batch 4:  Cost: 1.08855
# Accuracy: 0.6264
# ======================
# ready for training
# Epoch 33, CIFAR-10 Batch 5:  Cost: 1.13484
# Accuracy: 0.6458
# ======================
# ready for training
# Epoch 34, CIFAR-10 Batch 1:  Cost: 1.11829
# Accuracy: 0.646
# ======================
# ready for training
# Epoch 34, CIFAR-10 Batch 2:  Cost: 1.16521
# Accuracy: 0.6458
# ======================
# ready for training
# Epoch 34, CIFAR-10 Batch 3:  Cost: 1.19178
# Accuracy: 0.632
# ======================
# ready for training
# Epoch 34, CIFAR-10 Batch 4:  Cost: 1.1103
# Accuracy: 0.6334
# ======================
# ready for training
# Epoch 34, CIFAR-10 Batch 5:  Cost: 1.20986
# Accuracy: 0.6318
# ======================
# ready for training
# Epoch 35, CIFAR-10 Batch 1:  Cost: 1.20521
# Accuracy: 0.6418
# ======================
# ready for training
# Epoch 35, CIFAR-10 Batch 2:  Cost: 1.20707
# Accuracy: 0.6336
# ======================
# ready for training
# Epoch 35, CIFAR-10 Batch 3:  Cost: 1.07091
# Accuracy: 0.6276
# ======================
# ready for training
# Epoch 35, CIFAR-10 Batch 4:  Cost: 1.10371
# Accuracy: 0.6358
# ======================
# ready for training
# Epoch 35, CIFAR-10 Batch 5:  Cost: 1.20621
# Accuracy: 0.6254
# ======================
# ready for training
# Epoch 36, CIFAR-10 Batch 1:  Cost: 1.18399
# Accuracy: 0.6456
# ======================
# ready for training
# Epoch 36, CIFAR-10 Batch 2:  Cost: 1.13698
# Accuracy: 0.6282
# ======================
# ready for training
# Epoch 36, CIFAR-10 Batch 3:  Cost: 1.15621
# Accuracy: 0.6182
# ======================
# ready for training
# Epoch 36, CIFAR-10 Batch 4:  Cost: 1.10041
# Accuracy: 0.6092
# ======================
# ready for training
# Epoch 36, CIFAR-10 Batch 5:  Cost: 1.05834
# Accuracy: 0.6432
# ======================
# ready for training
# Epoch 37, CIFAR-10 Batch 1:  Cost: 1.11792
# Accuracy: 0.6316
# ======================
# ready for training
# Epoch 37, CIFAR-10 Batch 2:  Cost: 1.12456
# Accuracy: 0.6356
# ======================
# ready for training
# Epoch 37, CIFAR-10 Batch 3:  Cost: 1.01949
# Accuracy: 0.641
# ======================
# ready for training
# Epoch 37, CIFAR-10 Batch 4:  Cost: 1.10904
# Accuracy: 0.633
# ======================
# ready for training
# Epoch 37, CIFAR-10 Batch 5:  Cost: 1.1522
# Accuracy: 0.6462
# ======================
# ready for training
# Epoch 38, CIFAR-10 Batch 1:  Cost: 1.12448
# Accuracy: 0.6378
# ======================
# ready for training
# Epoch 38, CIFAR-10 Batch 2:  Cost: 1.10828
# Accuracy: 0.6312
# ======================
# ready for training
# Epoch 38, CIFAR-10 Batch 3:  Cost: 1.08848
# Accuracy: 0.642
# ======================
# ready for training
# Epoch 38, CIFAR-10 Batch 4:  Cost: 1.14395
# Accuracy: 0.65
# ======================
# ready for training
# Epoch 38, CIFAR-10 Batch 5:  Cost: 1.14215
# Accuracy: 0.6342
# ======================
# ready for training
# Epoch 39, CIFAR-10 Batch 1:  Cost: 1.13146
# Accuracy: 0.6208
# ======================
# ready for training
# Epoch 39, CIFAR-10 Batch 2:  Cost: 1.10955
# Accuracy: 0.6318
# ======================
# ready for training
# Epoch 39, CIFAR-10 Batch 3:  Cost: 1.03397
# Accuracy: 0.644
# ======================
# ready for training
# Epoch 39, CIFAR-10 Batch 4:  Cost: 1.17236
# Accuracy: 0.6028
# ======================
# ready for training
# Epoch 39, CIFAR-10 Batch 5:  Cost: 1.10717
# Accuracy: 0.6402
# ======================
# ready for training
# Epoch 40, CIFAR-10 Batch 1:  Cost: 1.21857
# Accuracy: 0.6252
# ======================
# ready for training
# Epoch 40, CIFAR-10 Batch 2:  Cost: 1.11813
# Accuracy: 0.6444
# ======================
# ready for training
# Epoch 40, CIFAR-10 Batch 3:  Cost: 1.21975
# Accuracy: 0.6538
# ======================
# ready for training
# Epoch 40, CIFAR-10 Batch 4:  Cost: 1.12245
# Accuracy: 0.6378
# ======================
# ready for training
# Epoch 40, CIFAR-10 Batch 5:  Cost: 1.1188
# Accuracy: 0.6368
# ======================
# ready for training
# Epoch 41, CIFAR-10 Batch 1:  Cost: 1.18945
# Accuracy: 0.6244
# ======================
# ready for training
# Epoch 41, CIFAR-10 Batch 2:  Cost: 1.10026
# Accuracy: 0.6404
# ======================
# ready for training
# Epoch 41, CIFAR-10 Batch 3:  Cost: 1.20892
# Accuracy: 0.6204
# ======================
# ready for training
# Epoch 41, CIFAR-10 Batch 4:  Cost: 1.10317
# Accuracy: 0.6532
# ======================
# ready for training
# Epoch 41, CIFAR-10 Batch 5:  Cost: 1.10943
# Accuracy: 0.6494
# ======================
# ready for training
# Epoch 42, CIFAR-10 Batch 1:  Cost: 1.10345
# Accuracy: 0.6436
# ======================
# ready for training
# Epoch 42, CIFAR-10 Batch 2:  Cost: 1.02175
# Accuracy: 0.6324
# ======================
# ready for training
# Epoch 42, CIFAR-10 Batch 3:  Cost: 1.13802
# Accuracy: 0.6566
# ======================
# ready for training
# Epoch 42, CIFAR-10 Batch 4:  Cost: 1.11653
# Accuracy: 0.6562
# ======================
# ready for training
# Epoch 42, CIFAR-10 Batch 5:  Cost: 1.16355
# Accuracy: 0.6508
# ======================
# ready for training
# Epoch 43, CIFAR-10 Batch 1:  Cost: 1.04122
# Accuracy: 0.6382
# ======================
# ready for training
# Epoch 43, CIFAR-10 Batch 2:  Cost: 1.13734
# Accuracy: 0.624
# ======================
# ready for training
# Epoch 43, CIFAR-10 Batch 3:  Cost: 1.17764
# Accuracy: 0.6412
# ======================
# ready for training
# Epoch 43, CIFAR-10 Batch 4:  Cost: 1.17256
# Accuracy: 0.6444
# ======================
# ready for training
# Epoch 43, CIFAR-10 Batch 5:  Cost: 1.18562
# Accuracy: 0.6474
# ======================
# ready for training
# Epoch 44, CIFAR-10 Batch 1:  Cost: 1.08012
# Accuracy: 0.6468
# ======================
# ready for training
# Epoch 44, CIFAR-10 Batch 2:  Cost: 1.18702
# Accuracy: 0.6486
# ======================
# ready for training
# Epoch 44, CIFAR-10 Batch 3:  Cost: 1.1223
# Accuracy: 0.6462
# ======================
# ready for training
# Epoch 44, CIFAR-10 Batch 4:  Cost: 1.09893
# Accuracy: 0.6506
# ======================
# ready for training
# Epoch 44, CIFAR-10 Batch 5:  Cost: 1.16927
# Accuracy: 0.6386
# ======================
# ready for training
# Epoch 45, CIFAR-10 Batch 1:  Cost: 0.934286
# Accuracy: 0.636
# ======================
# ready for training
# Epoch 45, CIFAR-10 Batch 2:  Cost: 1.07948
# Accuracy: 0.6468
# ======================
# ready for training
# Epoch 45, CIFAR-10 Batch 3:  Cost: 1.08752
# Accuracy: 0.6496
# ======================
# ready for training
# Epoch 45, CIFAR-10 Batch 4:  Cost: 1.1583
# Accuracy: 0.636
# ======================
# ready for training
# Epoch 45, CIFAR-10 Batch 5:  Cost: 1.10671
# Accuracy: 0.644
# ======================
# ready for training
# Epoch 46, CIFAR-10 Batch 1:  Cost: 1.08237
# Accuracy: 0.6394
# ======================
# ready for training
# Epoch 46, CIFAR-10 Batch 2:  Cost: 1.09085
# Accuracy: 0.652
# ======================
# ready for training
# Epoch 46, CIFAR-10 Batch 3:  Cost: 1.25777
# Accuracy: 0.5914
# ======================
# ready for training
# Epoch 46, CIFAR-10 Batch 4:  Cost: 1.0719
# Accuracy: 0.6278
# ======================
# ready for training
# Epoch 46, CIFAR-10 Batch 5:  Cost: 1.13567
# Accuracy: 0.6466
# ======================
# ready for training
# Epoch 47, CIFAR-10 Batch 1:  Cost: 1.11402
# Accuracy: 0.65
# ======================
# ready for training
# Epoch 47, CIFAR-10 Batch 2:  Cost: 1.29585
# Accuracy: 0.6338
# ======================
# ready for training
# Epoch 47, CIFAR-10 Batch 3:  Cost: 0.983441
# Accuracy: 0.66
# ======================
# ready for training
# Epoch 47, CIFAR-10 Batch 4:  Cost: 1.1329
# Accuracy: 0.6404
# ======================
# ready for training
# Epoch 47, CIFAR-10 Batch 5:  Cost: 1.1404
# Accuracy: 0.6568
# ======================
# ready for training
# Epoch 48, CIFAR-10 Batch 1:  Cost: 1.12306
# Accuracy: 0.6444
# ======================
# ready for training
# Epoch 48, CIFAR-10 Batch 2:  Cost: 1.13542
# Accuracy: 0.64
# ======================
# ready for training
# Epoch 48, CIFAR-10 Batch 3:  Cost: 1.17471
# Accuracy: 0.6568
# ======================
# ready for training
# Epoch 48, CIFAR-10 Batch 4:  Cost: 1.08539
# Accuracy: 0.6496
# ======================
# ready for training
# Epoch 48, CIFAR-10 Batch 5:  Cost: 0.997915
# Accuracy: 0.6482
# ======================
# ready for training
# Epoch 49, CIFAR-10 Batch 1:  Cost: 1.13518
# Accuracy: 0.6456
# ======================
# ready for training
# Epoch 49, CIFAR-10 Batch 2:  Cost: 1.32592
# Accuracy: 0.6358
# ======================
# ready for training
# Epoch 49, CIFAR-10 Batch 3:  Cost: 1.15582
# Accuracy: 0.6412
# ======================
# ready for training
# Epoch 49, CIFAR-10 Batch 4:  Cost: 1.10458
# Accuracy: 0.6606
# ======================
# ready for training
# Epoch 49, CIFAR-10 Batch 5:  Cost: 1.05452
# Accuracy: 0.6612
# ======================
# ready for training
# Epoch 50, CIFAR-10 Batch 1:  Cost: 1.12278
# Accuracy: 0.6544
# ======================
# ready for training
# Epoch 50, CIFAR-10 Batch 2:  Cost: 0.981171
# Accuracy: 0.6612
# ======================
# ready for training
# Epoch 50, CIFAR-10 Batch 3:  Cost: 1.05357
# Accuracy: 0.651
# ======================
# ready for training
# Epoch 50, CIFAR-10 Batch 4:  Cost: 1.15221
# Accuracy: 0.6546
# ======================
# ready for training
# Epoch 50, CIFAR-10 Batch 5:  Cost: 1.12558
# Accuracy: 0.647
# ======================

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_training.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for train_feature_batch, train_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: train_feature_batch, loaded_y: train_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# Testing Accuracy: 0.64482421875

# %% [markdown]
# ## Why 50-70% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 70%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
